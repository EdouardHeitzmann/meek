# %%
from votekit.pref_profile import PreferenceProfile
from votekit.cvr_loaders import load_csv, load_ranking_csv
from votekit.cleaning import remove_repeat_cands_rank_profile, remove_and_condense_rank_profile

Portland_D4 = load_ranking_csv("/home/nardo/research/contribute/3.3.0-MeekSTV/data/portland/Portland_D1_raw_votekit_format.csv", rank_cols= [1,2,3,4,5,6])


mama_this_is_garbaj = [key for key in Portland_D4.candidates if str(key).startswith("Write-in")]
mama_this_is_garbaj += [key for key in Portland_D4.candidates if str(key).startswith("Uncertified")]
mama_this_is_garbaj += [key for key in Portland_D4.candidates if str(key).startswith("rank")]
mama_this_is_garbaj += [key for key in Portland_D4.candidates if str(key).startswith("Rank")]
mama_this_is_garbaj += ["overvote", "undervote", "skipped"]

new_profile = remove_repeat_cands_rank_profile(Portland_D4)
new_profile = remove_and_condense_rank_profile(mama_this_is_garbaj, new_profile)
new_profile = new_profile.group_ballots()

new_profile
# Out:
# RankProfile
# Maximum ranking length: 6
# Candidates: ('Steph Routh', 'Write-in-120', 'Rank 6', 'Jamie Dunphy', 'Doug Clove', 'Joe Furi', 'Candace Avalos', 'Cayle Tern', 'Peggy Sue Owens', 'overvote', 'Rank 5', 'Noah Ernst', 'Joe Allen', 'Rank 1', 'Thomas Shervey', 'Rank 4', 'Uncertified Write In', 'Michael (Mike) Sands', 'Write-in-122', 'Rank 3', 'Terrence Hayes', 'David Linn', 'Rank 2', 'Timur Ender', 'Deian Salazar', 'Write-in-121', 'Loretta Smith')
# Candidates who received votes: ('Steph Routh', 'Write-in-120', 'Rank 6', 'Jamie Dunphy', 'Doug Clove', 'Joe Furi', 'Candace Avalos', 'Cayle Tern', 'Peggy Sue Owens', 'overvote', 'Rank 5', 'Noah Ernst', 'Joe Allen', 'Rank 1', 'Thomas Shervey', 'Rank 4', 'Uncertified Write In', 'Michael (Mike) Sands', 'Write-in-122', 'Rank 3', 'Terrence Hayes', 'David Linn', 'Rank 2', 'Timur Ender', 'Deian Salazar', 'Write-in-121', 'Loretta Smith')
# Total number of Ballot objects: 43670
# Total weight of Ballot objects: 43670.0
# /home/nardo/research/contribute/3.3.0-MeekSTV/src/votekit/pref_profile/cleaned_pref_profile.py:159: UserWarning: Grouping the ballots of a CleanedRankProfile will return a RankProfile since this operation resets ballot indices.
#   warnings.warn(
# RankProfile
# Maximum ranking length: 6
# Candidates: ('Steph Routh', 'Thomas Shervey', 'Jamie Dunphy', 'Joe Furi', 'Doug Clove', 'Candace Avalos', 'Michael (Mike) Sands', 'Cayle Tern', 'Peggy Sue Owens', 'Terrence Hayes', 'David Linn', 'Noah Ernst', 'Timur Ender', 'Deian Salazar', 'Loretta Smith', 'Joe Allen')
# Candidates who received votes: ('Steph Routh', 'Jamie Dunphy', 'Doug Clove', 'Cayle Tern', 'Candace Avalos', 'Joe Furi', 'Peggy Sue Owens', 'Noah Ernst', 'Joe Allen', 'Thomas Shervey', 'Michael (Mike) Sands', 'Terrence Hayes', 'David Linn', 'Timur Ender', 'Deian Salazar', 'Loretta Smith')
# Total number of Ballot objects: 18723
# Total weight of Ballot objects: 42678.0

# %%
import pickle

with open("/home/nardo/research/contribute/3.3.0-MeekSTV/data/portland/Portland_D1.pkl", "wb") as f:
    pickle.dump(new_profile, f)
